# %% [markdown]
# # PANDAS:

# %%
import pandas as pd

# %%
pd.read_csv('xy1.csv')
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
#To consider first row as column header or not.
df = pd.read_csv('xy1.csv')

# %%
df
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Dataframe is a tabular structure of data

# %%
df.head()
#Shows only first 5 rows by default if more records / data
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
df.head(2)
#shows top 2 data
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world

# %%
df.tail()
#shows bottom 2 data (bottom 5 rows by default if more records)
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
df.tail(2)
# Out:
#    a  b  c  d message
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
df.dtypes
#tells datatype of column
# Out:
# a           int64
# b           int64
# c           int64
# d           int64
# message    object
# dtype: object

# %%
df
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
#accessing only particular column
df['d']
# Out:
# 0    4
# 1    8
# 2    2
# Name: d, dtype: int64

# %%
type(df['d'])
#Series - for fetching / reading a one single row or column
#List doesn't show index but Series does show a index
# Out:
# pandas.core.series.Series

# %%
#List doesnt show indexes
l=[1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
#converting series into list
list(df['d'])
# Out:
# [4, 8, 2]

# %%
#entire colsArithmeticError
type(df[['d']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['d']]
# Out:
#    d
# 0  4
# 1  8
# 2  2

# %%
df['a']
# Out:
# 0    1
# 1    5
# 2    9
# Name: a, dtype: int64

# %%
df['a','d']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('a', 'd')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-951810254976> in <module>
# ----> 1 df['a','d']
#
# ...

# %%
#To access multiple columns, pass it inside a list:
df[['a','d']]
# Out:
#    a  d
# 0  1  4
# 1  5  8
# 2  9  2

# %%
type(df[['a','d']])
# Out:
# pandas.core.frame.DataFrame

# %%
#With first row value as header:
#By default:
pd.read_csv('xy1.csv')
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
#With first row value as value itself: By default, seperator is comma
pd.read_csv('xy1.csv',header=None)
# Out:
#    0  1  2  3        4
# 0  a  b  c  d  message
# 1  1  2  3  4    hello
# 2  5  6  7  8    world
# 3  9  0  1  2   vishal

# %%
#for tab separator data (.tsv). It uses default seperator as '\t'
#pd.read_table('test.tsv')

# %%
#To read TSV file using CSV
#pd.read_csv('test.tsv',sep='\t')

# %%
df
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
#To change the column names using name parameter:
pd.read_csv('xy1.csv',header=None,names=['x','y','z','a','b'])
# Out:
#    x  y  z  a        b
# 0  a  b  c  d  message
# 1  1  2  3  4    hello
# 2  5  6  7  8    world
# 3  9  0  1  2   vishal

# %%
#Additional additional column name gives NaN value
df2 = pd.read_csv('xy1.csv',header=None,names=['x','y','z','a','b','c'])
df2
# Out:
#    x  y  z  a        b   c
# 0  a  b  c  d  message NaN
# 1  1  2  3  4    hello NaN
# 2  5  6  7  8    world NaN
# 3  9  0  1  2   vishal NaN

# %%
#If passing lesser number of column names
pd.read_csv('xy1.csv',header=None,names=['x','y','z'])
# Out:
#      x  y        z
# a b  c  d  message
# 1 2  3  4    hello
# 5 6  7  8    world
# 9 0  1  2   vishal

# %%
df
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
#To treat column as index:
pd.read_csv('xy1.csv',index_col=['a'])
# Out:
#    b  c  d message
# a
# 1  2  3  4   hello
# 5  6  7  8   world
# 9  0  1  2  vishal

# %%
df = pd.read_csv('xy1.csv',header=None,names=['x','y','z'])
df
# Out:
#      x  y        z
# a b  c  d  message
# 1 2  3  4    hello
# 5 6  7  8    world
# 9 0  1  2   vishal

# %%
#to create multiple key index:
pd.read_csv('xy1.csv',index_col=['a','b'])
# Out:
#      c  d message
# a b
# 1 2  3  4   hello
# 5 6  7  8   world
# 9 0  1  2  vishal

# %% [raw]
# Input file for below example:
# #hi
# #how are you
# a,b,c,d,message
# 1,2,3,4,vishal
# #I am good
# 5,6,7,8,ganesan
# 9,0,1,2,sudha
# #How about you
# 3,4,5,6,vaishu
# #I am good as well

# %%
df1 = pd.read_csv('xy2.csv',skiprows=[0,1,4,7,9])
df1
# Out:
#    a  b  c  d  message
# 0  1  2  3  4   vishal
# 1  5  6  7  8  ganesan
# 2  9  0  1  2    sudha
# 3  3  4  5  6   vaishu

# %%
#If we give without skipping it will throw error:
pd.read_csv('xy2.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-63-795353e93284> in <module>
#       1 #If we give without skipping it will throw error:
# ----> 2 pd.read_csv('xy2.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
#If passing lesser number of column names
df2 = pd.read_csv('xy1.csv',header=None,names=['x','y','z','a','b','c'])
df2
#Has NotaNumber
# Out:
#    x  y  z  a        b   c
# 0  a  b  c  d  message NaN
# 1  1  2  3  4    hello NaN
# 2  5  6  7  8    world NaN
# 3  9  0  1  2   vishal NaN

# %%
#Sample file for NaN example:
pd.read_csv('xy1.csv')
# Out:
#    a  b  c  d message
# 0  1  2  3  4   hello
# 1  5  6  7  8   world
# 2  9  0  1  2  vishal

# %%
#To consider some values as 'NaN'
pd.read_csv('xy1.csv',na_values=['a',1])
# Out:
#      a  b    c  d message
# 0  NaN  2  3.0  4   hello
# 1  5.0  6  7.0  8   world
# 2  9.0  0  NaN  2  vishal

# %%
#Present Working directory:

# %%
pwd()
# Out:
# 'C:\\Users\\ELCOT\\Python Ineuron'

# %%
#Example for reading from incorrect location error is thrown:
pd.read_excel('test.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-82-acabad633015> in <module>
#       1 #Example for reading from incorrect location error is thrown:
# ----> 2 pd.read_excel('test.xlsx')
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# ...

# %%
#So have it readed from its original location, you will get unicode issue :
pd.read_excel('C:\Users\ELCOT\Downloads\365 Data Science\Intro to Excel\4. Data Entry - Lecture.xlsx')
# Out:
#   File "<ipython-input-85-e533c01a2bd9>", line 2
#     pd.read_excel('C:\Users\ELCOT\Downloads\365 Data Science\Intro to Excel\4. Data Entry - Lecture.xlsx')
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
#To resolve unicode issue:
pd.read_excel(r'C:\Users\ELCOT\Downloads\365 Data Science\Intro to Excel\4. Data Entry - Lecture.xlsx')
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN     Monday         1.0
# 3         NaN         NaN         NaN    Tuesday         2.0
# 4         NaN         NaN         NaN  Wednesday         3.0
# 5         NaN         NaN         NaN   Thursday         4.0
# 6         NaN         NaN         NaN     Friday         5.0
# 7         NaN         NaN         NaN   Saturday         6.0
# 8         NaN         NaN         NaN     Sunday         7.0

# %%
#Alternate to adding 'r' is using '\\':

df3 = pd.read_excel('C:\\Users\\ELCOT\\Downloads\\365 Data Science\\Intro to Excel\\4. Data Entry - Lecture.xlsx')
df3
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN     Monday         1.0
# 3         NaN         NaN         NaN    Tuesday         2.0
# 4         NaN         NaN         NaN  Wednesday         3.0
# 5         NaN         NaN         NaN   Thursday         4.0
# 6         NaN         NaN         NaN     Friday         5.0
# 7         NaN         NaN         NaN   Saturday         6.0
# 8         NaN         NaN         NaN     Sunday         7.0

# %%
#Alternate to adding 'r' and '\\' is using '/':

df3 = pd.read_excel('C:/Users/ELCOT/Downloads/365 Data Science/Intro to Excel/4. Data Entry - Lecture.xlsx',header=None)
df3

#Here data is read only from one sheet
# Out:
#     0   1   2          3    4
# 0 NaN NaN NaN        NaN  NaN
# 1 NaN NaN NaN        NaN  NaN
# 2 NaN NaN NaN        NaN  NaN
# 3 NaN NaN NaN     Monday  1.0
# 4 NaN NaN NaN    Tuesday  2.0
# 5 NaN NaN NaN  Wednesday  3.0
# 6 NaN NaN NaN   Thursday  4.0
# 7 NaN NaN NaN     Friday  5.0
# 8 NaN NaN NaN   Saturday  6.0
# 9 NaN NaN NaN     Sunday  7.0

# %%
#To read data from particular sheet:

#pd.read_excel('C:/Users/ELCOT/Downloads/365 Data Science/Intro to Excel/4. Data Entry - Lecture.xlsx',sheet_name='Sheet1')

# %%
df3.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3     object
# 4    float64
# dtype: object

# %%
df3[0]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: 0, dtype: float64

# %%
df3[[0]]
# Out:
#     0
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN
# 7 NaN
# 8 NaN
# 9 NaN

# %% [raw]
# #Read table from html in tabular form:
# https://www.basketball-reference.com/leagues/NBA_2015_totals.html
#
# Fetches only the data which is inside table tag in html page
# If there are multiple tables, each tables is given in indexes.

# %%
df5 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
df
# Out:
#      x  y        z
# a b  c  d  message
# 1 2  3  4    hello
# 5 6  7  8    world
# 9 0  1  2   vishal

# %%
type(df5)
# Out:
# list

# %%
len(df5)
#only 1 table. Lisyt has stored all data in 0th index.
# Out:
# 1

# %%
df5[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df5[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df5[0].head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
#To find column names:
df5[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [raw]
# Thru Beautiful soap, we will be able to get any type of data available on any website

# %%
#If the original csv file data is separated by \t tab: If you import, it won't be in proper readable format.
#Use sep

#Link:https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv

#pd.read_csv('https://www.basketball-reference.com/leagues/NBA_2015_totals.html',sep='\t')

# %%
df6 = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv',sep='\t')

# %%
df6
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df6.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df6[['Ticket','Fare','Sex']]
# Out:
#                Ticket     Fare     Sex
# 0           A/5 21171   7.2500    male
# 1            PC 17599  71.2833  female
# 2    STON/O2. 3101282   7.9250  female
# 3              113803  53.1000  female
# 4              373450   8.0500    male
# ..                ...      ...     ...
# 151            113776  66.6000  female
# 152        A.5. 11206   8.0500    male
# 153          A/5. 851  14.5000    male
# 154         Fa 265302   7.3125    male
# 155          PC 17597  61.3792    male
#
# [156 rows x 3 columns]

# %%
#To read particular number of rows (nrows):
pd.read_excel(r'C:\Users\ELCOT\Downloads\365 Data Science\Intro to Excel\4. Data Entry - Lecture.xlsx',nrows=4)
#Loads only 4 records while selection itself
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN     Monday         1.0
# 3         NaN         NaN         NaN    Tuesday         2.0

# %%
pd.read_excel(r'C:\Users\ELCOT\Downloads\365 Data Science\Intro to Excel\4. Data Entry - Lecture.xlsx').head(4)
#Load all the records (10k recs) and then choose top 4
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4
# 0         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN     Monday         1.0
# 3         NaN         NaN         NaN    Tuesday         2.0

# %%
#Restricting depending on data size: Reads only 300 bytes of data.
#Example if size of 1 row is 170, it will be able to read only 1 and half row.
#300 bytes of data is passed from HD to RAM. Iterate over object to get output.
pd.read_csv('xy1.csv',chunksize=300)

# %%
#write into file
df6.to_csv(r'C:\Users\ELCOT\Downloads\ineuron Python\titanic.csv')
#output will be stored along with index

# %%
pwd()
# Out:
# 'C:\\Users\\ELCOT\\Python Ineuron'

# %%
#formatting back to tsv
df6.to_csv(r'C:\Users\ELCOT\Downloads\ineuron Python\titanic1.tsv',sep='\t')

# %%
df6.to_csv(r'C:\Users\ELCOT\Downloads\ineuron Python\titanic2.tsv',sep=',')
#data is separated by commas.

# %%
df6.to_csv(r'C:\Users\ELCOT\Downloads\ineuron Python\titanic3.tsv',sep='@')
#data is separated by @.

# %%
df6.to_csv(r'C:\Users\ELCOT\Downloads\ineuron Python\titanic.csv',index=False)
#output will be stored not along with index. Index will be removed

# %%
#If header is true, output will have header.
#If header is false, output will not have header.

# %%
df6.to_csv(r'C:\Users\ELCOT\Downloads\ineuron Python\titanic.csv',index=False,header=True)

# %%
df1
# Out:
#    a  b  c  d  message
# 0  1  2  3  4   vishal
# 1  5  6  7  8  ganesan
# 2  9  0  1  2    sudha
# 3  3  4  5  6   vaishu

# %%
#to rename the column:
df1.to_csv('df1out.csv',index=False,header=False,columns=['a','b','c','d','message'])
#both column name in dataframe and new column name should be same

# %%
#Data which is stored in binary format is pickle file. Binary file.
#object is stored in byte format.
#Byte to obj - deserialization - read. Obj to Byte is serialization - write.
#Its notin human readable format.

df1.to_pickle(r'C:\Users\ELCOT\Downloads\ineuron Python\testpick')

# %%
pd.read_pickle(r'C:\Users\ELCOT\Downloads\ineuron Python\testpick')
# Out:
#    a  b  c  d  message
# 0  1  2  3  4   vishal
# 1  5  6  7  8  ganesan
# 2  9  0  1  2    sudha
# 3  3  4  5  6   vaishu
